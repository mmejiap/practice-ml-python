# %%
import os
import sys
import json
import spotipy
import webbrowser
import spotipy.util as util
from json.decoder import JSONDecodeError

# %%
# Get the username from terminal
username = sys.argv[1]
scope = 'user-read-private user-read-playback-state user-modify-playback-state'

# %%
# Erase cache and prompt for user permission
try:
    token = util.prompt_for_user_token(username, scope) # add scope
except (AttributeError, JSONDecodeError):
    os.remove(f".cache-{username}")
    token = util.prompt_for_user_token(username, scope) # add scope

# %%
# Create our spotify object with permissions
spotifyObject = spotipy.Spotify(auth=token)

# %%
# Get current device
devices = spotifyObject.devices()
deviceID = devices['devices'][0]['id']

# %%
# Current track information
track = spotifyObject.current_user_playing_track()
artist = track['item']['artists'][0]['name']
track = track['item']['name']

# %%
if artist != "":
    print("Currently playing " + artist + " - " + track)
# Out:
# Currently playing Becky G - Sin Pijama

# %%
# User information
user = spotifyObject.current_user()
displayName = user['display_name']
followers = user['followers']['total']

# %%
followers
# Out:
# 9

# %%
# Loop
while True:
    # Main Menu
    print()
    print(">>> Welcome to Spotipy " + str(displayName) + "!")
    print(">>> You have " + str(followers) + " followers.")
    print()
    print("0 - Search for an artist")
    print("1 - exit")
    print()
    choice = input("Your choice: ")

    if choice == "0":
        print()
        searchQuery = input("Ok, what's their name?: ")
        print()

        # Get search results
        searchResults = spotifyObject.search(searchQuery,1,0,"artist")

        # Artist details
        artist = searchResults['artists']['items'][0]
        print(artist['name'])
        print(str(artist['followers']['total']) + " followers")
        print(artist['genres'][0])
        print()
        webbrowser.open(artist['images'][0]['url'])
        artistID = artist['id']


        # Album and track details
        trackURIs = []
        trackArt = []
        z = 0

        # Extract album data
        albumResults = spotifyObject.artist_albums(artistID)
        albumResults = albumResults['items']

        for item in albumResults:
            print("ALBUM: " + item['name'])
            albumID = item['id']
            albumArt = item['images'][0]['url']

            # Extract track data
            trackResults = spotifyObject.album_tracks(albumID)
            trackResults = trackResults['items']

            for item in trackResults:
                print(str(z) + ": " + item['name'])
                trackURIs.append(item['uri'])
                trackArt.append(albumArt)
                z+=1
            print()

        # See album art
        while True:
            songSelection = input("Enter a song number to see album art and play the song (x to exit): ") # and play the song
            if songSelection == "x":
                break
            trackSelectionList = []
            trackSelectionList.append(trackURIs[int(songSelection)])
            spotifyObject.start_playback(deviceID, None, trackSelectionList) # added
            webbrowser.open(trackArt[int(songSelection)])

    if choice == "1":
        break

    # print(json.dumps(trackResults, sort_keys=True, indent=4))
# Out:
# >>> Welcome to Spotipy None!
# >>> You have 9 followers.
#
# 0 - Search for an artist
# 1 - exit
#
# Your choice: 0
#
# Ok, what's their name?: Drake
#
# Drake
# 23472706 followers
# canadian hip hop
#
# ALBUM: Scorpion
# 0: Survival
# 1: Nonstop
# 2: Elevate
# 3: Emotionless
# 4: God's Plan
# 5: I'm Upset
# 6: 8 Out Of 10
# 7: Mob Ties
# 8: Can’t Take A Joke
# 9: Sandra’s Rose
# 10: Talk Up (feat. Jay-Z)
# 11: Is There More
# 12: Peak
# 13: Summer Games
# 14: Jaded
# 15: Nice For What
# 16: Finesse
# 17: Ratchet Happy Birthday
# 18: That’s How You Feel
# 19: Blue Tint
# 20: In My Feelings
# 21: Don’t Matter To Me (feat. Michael Jackson)
# 22: After Dark (feat. Static Major &amp; Ty Dolla $ign)
# 23: Final Fantasy
# 24: March 14
#
# ALBUM: More Life
# 25: Free Smoke
# 26: No Long Talk
# 27: Passionfruit
# 28: Jorja Interlude
# 29: Get It Together
# 30: Madiba Riddim
# 31: Blem
# 32: 4422
# 33: Gyalchester
# 34: Skepta Interlude
# 35: Portland
# 36: Sacrifices
# 37: Nothings Into Somethings
# 38: Teenage Fever
# 39: KMT
# 40: Lose You
# 41: Can't Have Everything
# 42: Glow
# 43: Since Way Back
# 44: Fake Love
# 45: Ice Melts
# 46: Do Not Disturb
#
# ALBUM: Views
# 47: Keep The Family Close
# 48: 9
# 49: U With Me?
# 50: Feel No Ways
# 51: Hype
# 52: Weston Road Flows
# 53: Redemption
# 54: With You
# 55: Faithful
# 56: Still Here
# 57: Controlla
# 58: One Dance
# 59: Grammys
# 60: Childs Play
# 61: Pop Style
# 62: Too Good
# 63: Summers Over Interlude
# 64: Fire & Desire
# 65: Views
# 66: Hotline Bling
#
# ALBUM: Views
# 67: Keep The Family Close
# 68: 9
# 69: U With Me?
# 70: Feel No Ways
# 71: Hype
# 72: Weston Road Flows
# 73: Redemption
# 74: With You
# 75: Faithful
# 76: Still Here
# 77: Controlla
# 78: One Dance
# 79: Grammys
# 80: Childs Play
# 81: Pop Style
# 82: Too Good
# 83: Summers Over Interlude
# 84: Fire & Desire
# 85: Views
# 86: Hotline Bling
#
# ALBUM: What A Time To Be Alive
# 87: Digital Dash
# 88: Big Rings
# 89: Live From The Gutter
# 90: Diamonds Dancing
# 91: Scholarships
# 92: Plastic Bag
# 93: I'm The Plug
# 94: Change Locations
# 95: Jumpman
# 96: Jersey
# 97: 30 for 30 Freestyle
#
# ALBUM: If You're Reading This It's Too Late
# 98: Legend
# 99: Energy
# 100: 10 Bands
# 101: Know Yourself
# 102: No Tellin'
# 103: Madonna
# 104: 6 God
# 105: Star67
# 106: Preach
# 107: Wednesday Night Interlude
# 108: Used To
# 109: 6 Man
# 110: Now & Forever
# 111: Company
# 112: You & The 6
# 113: Jungle
# 114: 6PM In New York
#
# ALBUM: Nothing Was The Same (Deluxe)
# 115: Tuscan Leather
# 116: Furthest Thing
# 117: Started From The Bottom
# 118: Wu-Tang Forever
# 119: Own It
# 120: Worst Behavior
# 121: From Time
# 122: Hold On, We're Going Home
# 123: Connect
# 124: The Language
# 125: 305 To My City
# 126: Too Much
# 127: Pound Cake / Paris Morton Music 2
# 128: Come Thru
# 129: All Me
# 130: The Motion
#
# ALBUM: Nothing Was The Same
# 131: Tuscan Leather
# 132: Furthest Thing
# 133: Started From the Bottom
# 134: Wu-Tang Forever
# 135: Own It
# 136: Worst Behavior
# 137: From Time
# 138: Hold On, We're Going Home
# 139: Connect
# 140: The Language
# 141: 305 To My City
# 142: Too Much
# 143: Pound Cake / Paris Morton Music 2
#
# ALBUM: Take Care (Deluxe)
# 144: Over My Dead Body
# 145: Shot For Me
# 146: Headlines
# 147: Crew Love
# 148: Take Care
# 149: Marvins Room
# 150: Buried Alive Interlude
# 151: Under Ground Kings
# 152: We'll Be Fine
# 153: Make Me Proud
# 154: Lord Knows
# 155: Cameras / Good Ones Go Interlude - Medley
# 156: Doing It Wrong
# 157: The Real Her
# 158: Look What You've Done
# 159: HYFR (Hell Ya Fucking Right)
# 160: Practice
# 161: The Ride
# 162: The Motto
#
# ALBUM: Thank Me Later (Int'l Version)
# 163: Fireworks
# 164: Karaoke
# 165: The Resistance
# 166: Over
# 167: Show Me A Good Time
# 168: Up All Night
# 169: Fancy
# 170: Shut It Down
# 171: Unforgettable
# 172: Light Up
# 173: Miss Me
# 174: Cece's Interlude
# 175: Find Your Love
# 176: Thank Me Now
# 177: Best I Ever Had
#
# ALBUM: So Far Gone
# 178: Houstatlantavegas
# 179: Successful
# 180: Best I Ever Had
# 181: Uptown
# 182: I'm Goin In
# 183: The Calm
# 184: Fear
#
# ALBUM: I'm Upset
# 185: I'm Upset
#
# ALBUM: Nice For What
# 186: Nice For What
#
# ALBUM: Look Alive (feat. Drake)
# 187: Look Alive (feat. Drake)
#
# ALBUM: Scary Hours
# 188: God's Plan
# 189: Diplomatic Immunity
#
# ALBUM: Diplomatic Immunity
# 190: Diplomatic Immunity
#
# ALBUM: Signs
# 191: Signs
#
# ALBUM: No Frauds
# 192: No Frauds
#
# ALBUM: Two Birds, One Stone
# 193: Two Birds, One Stone
#
# ALBUM: Pop Style
# 194: Pop Style
#
# Enter a song number to see album art and play the song (x to exit): 4

# %%
spotifyObject.
